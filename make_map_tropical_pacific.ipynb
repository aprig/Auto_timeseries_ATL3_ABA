# %%
# Author: Arthur Prigent
# Email: aprigent@geomar.de

#### DATA ####

# https://downloads.psl.noaa.gov/Datasets/
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
path_oi_wk = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2/'
ssta_pac_norm_oi_wk = read_data_compute_anomalies_week_map_pac(path_oi_wk)

# %%
plot_map_ssta_pac(ssta_pac_norm_oi_wk)
