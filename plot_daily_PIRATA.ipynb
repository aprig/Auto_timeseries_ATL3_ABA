# %%
# Author: Arthur Prigent
# Email: aprigent@geomar.de
# http://tds0.ifremer.fr/thredds/catalog/CORIOLIS-OCEANSITES-GDAC-OBS/long_timeseries/PIRATA/catalog.html

# %%
from functions import *
import warnings
warnings.filterwarnings("ignore")
now = datetime.datetime.now()
date_time = now.strftime("%d/%m/%Y")

from IPython.display import Image

# %%
path_data = 'http://tds0.ifremer.fr/thredds/dodsC/CORIOLIS-OCEANSITES-GDAC-OBS/long_timeseries/PIRATA/'
temp_35w,temp_23w,temp_10w,temp_0w = read_pirata_temp(path_data)

# %%
plot_pirata_temp(temp_35w,temp_23w,temp_10w,temp_0w)

# %% [markdown]
# # 35$^{\circ}$W

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n35w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n35w.gif"/>

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n35w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n35w.gif"/>

# %% [markdown]
# # 23$^{\circ}$W

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n23w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n23w.gif"/>

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n23w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n23w.gif"/>

# %% [markdown]
# # 10$^{\circ}$W

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n10w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n10w.gif"/>

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n10w.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/cur_0n10w.gif"/>

# %% [markdown]
# # 0$^{\circ}$E

# %%
Image(url='https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n0e.gif')
# Out:
# <img src="https://www.pmel.noaa.gov/tao/drupal/pirata-display/gif/buoy_0n0e.gif"/>
