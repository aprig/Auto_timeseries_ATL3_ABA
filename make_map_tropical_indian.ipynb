# %%
# Author: Arthur Prigent
# Email: aprigent@geomar.de

#### DATA ####
# https://downloads.psl.noaa.gov/Datasets/
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
path_oi = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2/'
ssta_ind_norm_oi_wk = read_data_compute_anomalies_map_ind(path_oi)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/envs/py3_std/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/envs/py3_std/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /anaconda3/envs/py3_std/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     420             ssl_context=context,
# --> 421             tls_in_tls=tls_in_tls,
#     422         )
#
# ...

# %%
plot_map_ssta_ind(ssta_ind_norm_oi)
