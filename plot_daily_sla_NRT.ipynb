# %%
# Author: Arthur Prigent
# Email: aprigent@geomar.de

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from datetime import *
now = datetime.now()
date_time = now.strftime("%d/%m/%Y")

# %%
ds = xr.open_dataset('https://www.star.nesdis.noaa.gov/thredds/dodsC/AltimetryBlendedGlobal/rads_global_nrt_sla_latest.nc')

# %%
ds_sub = ds.where((ds.latitude>50)&(ds.latitude<65)&(ds.longitude>-65)&(ds.longitude<-35),drop=True)

# %%
ds.attrs
# Out:
# {'Conventions': 'CF-1.6',
#  'title': 'Daily merged sea surface height anomalies from altimetry',
#  'ncei_template_version': 'NCEI_NetCDF_Grid_Template_v2.0',
#  'institution': 'NOAA/NESDIS Center for Satellite Applications and Research',
#  'creator_email': 'Eric.Leuliette@noaa.gov',
#  'creator_name': 'Eric.Leuliette@noaa.gov',
#  'date_created': '2022-07-07T12:00:20Z',
#  'date_modified': '2022-07-07T12:00:20Z',
#  'cw%3asatellite': 'SARAL\nJason-3\nSentinel-3A\nSentinel-3B',
#  'cw%3atime': '26474\n26475\n26476\n26477\n26478\n26479\n26480\n26481\n26482\n26483',
#  'cw%3aprocessing_algorithm': 'RADS 4.4.0',
#  'cw%3aproduct_status': 'Experimental',
#  'geospatial_lat_max': 89.875,
#  'geospatial_lat_min': -89.875,
#  'geospatial_lat_resolution': 0.25,
#  'geospatial_lat_units': 'degrees_north',
#  'geospatial_lon_max': 359.875,
#  'geospatial_lon_min': 0.125,
#  'geospatial_lon_resolution': 0.25,
#  'geospatial_lon_units': 'degrees_east',
#  'geospatial_vertical_max': 0.0,
#  'geospatial_vertical_min': 0.0,
#  'geospatial_vertical_positive': 'down',
#  'geospatial_vertical_resolution': 'point',
#  'geospatial_vertical_units': 'm',
#  'source': 'Altimetry measurements'}

# %%
f,ax = plt.subplots(1,1,figsize=[10,10])
ftz=15
cmap = plt.cm.bwr
bounds= np.arange(-0.2,0.22,0.02)
bounds1= [-0.2,-0.14,-0.1,-0.06,0.06,0.1,0.14,0.2]
ax.set_title(str(ds_sub.time.values[0])[:10],fontsize=ftz)
cs1 = ax.contour(ds_sub.longitude,ds_sub.latitude,ds_sub.sla[0,:,:],colors='black',levels=bounds1,extend='both')
p1 = ax.contourf(ds_sub.longitude,ds_sub.latitude,ds_sub.sla[0,:,:],cmap=cmap,levels=bounds,extend='both')

cbar = plt.colorbar(p1)
cbar.ax.tick_params(labelsize=ftz)
ax.set_xlabel('Longitude ($^{\circ}$)',fontsize=ftz)
ax.set_ylabel('Latitude ($^{\circ}$)',fontsize=ftz)
ax.tick_params(labelsize=ftz)
ax.clabel(cs1, inline=1, fontsize=ftz-5)

cbar.set_label(r' SLA (m)', size=ftz)
ax.text(0.45,0.95,'Updated '+date_time,transform=ax.transAxes,
           size=ftz,
           weight='bold')
# Out:
# Text(0.45, 0.95, 'Updated 13/07/2022')

# %%
# Out:
# {'Conventions': 'CF-1.6',
#  'title': 'Daily merged sea surface height anomalies from altimetry',
#  'ncei_template_version': 'NCEI_NetCDF_Grid_Template_v2.0',
#  'institution': 'NOAA/NESDIS Center for Satellite Applications and Research',
#  'creator_email': 'Eric.Leuliette@noaa.gov',
#  'creator_name': 'Eric.Leuliette@noaa.gov',
#  'date_created': '2022-07-07T12:00:20Z',
#  'date_modified': '2022-07-07T12:00:20Z',
#  'cw%3asatellite': 'SARAL\nJason-3\nSentinel-3A\nSentinel-3B',
#  'cw%3atime': '26474\n26475\n26476\n26477\n26478\n26479\n26480\n26481\n26482\n26483',
#  'cw%3aprocessing_algorithm': 'RADS 4.4.0',
#  'cw%3aproduct_status': 'Experimental',
#  'geospatial_lat_max': 89.875,
#  'geospatial_lat_min': -89.875,
#  'geospatial_lat_resolution': 0.25,
#  'geospatial_lat_units': 'degrees_north',
#  'geospatial_lon_max': 359.875,
#  'geospatial_lon_min': 0.125,
#  'geospatial_lon_resolution': 0.25,
#  'geospatial_lon_units': 'degrees_east',
#  'geospatial_vertical_max': 0.0,
#  'geospatial_vertical_min': 0.0,
#  'geospatial_vertical_positive': 'down',
#  'geospatial_vertical_resolution': 'point',
#  'geospatial_vertical_units': 'm',
#  'source': 'Altimetry measurements'}
